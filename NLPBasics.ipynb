# %% [markdown]
# <a href="https://colab.research.google.com/github/rvjh/PythonPractice/blob/main/NLPBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
para = 'Big data is like teenage sex. everyone talks about it. nobody really knows how to do it. everyone thinks everyone else is doing it. so everyone claims they are doing it.'

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> l
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] bcp47............... BCP-47 Language Tags
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
# ...

# %%
## for sentence tokenizaton
s = nltk.sent_tokenize(para)
s
# Out:
# ['Big data is like teenage sex.',
#  'everyone talks about it.',
#  'nobody really knows how to do it.',
#  'everyone thinks everyone else is doing it.',
#  'so everyone claims they are doing it.']

# %%
## for word

w = nltk.word_tokenize(para)
w
# Out:
# ['Big',
#  'data',
#  'is',
#  'like',
#  'teenage',
#  'sex',
#  '.',
#  'everyone',
#  'talks',
#  'about',
#  'it',
#  '.',
#  'nobody',
#  'really',
#  'knows',
#  'how',
#  'to',
#  'do',
#  'it',
#  '.',
#  'everyone',
#  'thinks',
#  'everyone',
#  'else',
#  'is',
#  'doing',
#  'it',
#  '.',
#  'so',
#  'everyone',
#  'claims',
#  'they',
#  'are',
#  'doing',
#  'it',
#  '.']

# %% [markdown]
# # Lemmatization and Stemming

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

s = nltk.sent_tokenize(para)

# %%
## stemming
stemmer = PorterStemmer()
for i in range(len(s)):
  words = nltk.word_tokenize(s[i])
  words = [stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
  s[i] = ' '.join(words)

# %%
s
# Out:
# ['big data like teenag sex .',
#  'everyon talk .',
#  'nobodi realli know .',
#  'everyon think everyon el .',
#  'everyon claim .']
