# %% [markdown]
# <a href="https://colab.research.google.com/github/rvjh/PythonPractice/blob/main/Time_Series_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_scv_data = pd.read_csv("/content/Index2018.csv")

# %%
df_comp = raw_scv_data.copy()
df_comp.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
df_comp.columns
# Out:
# Index(['date', 'spx', 'dax', 'ftse', 'nikkei'], dtype='object')

# %%
df_comp.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %%
# count missing values ->

df_comp.isna().sum()
# Out:
# date      0
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %%
df_comp.spx.plot(figsize=(20,5),title = 'S&P 500 Prices')
plt.show()

# %%
df_comp.dax.plot(figsize=(20,5),title = 'DAX 30 Prices')
plt.show()

# %%
df_comp.ftse.plot(figsize=(20,5),title = 'FTSE 100 Prices')
plt.show()

# %%
df_comp.spx.plot(figsize=(20,5),title = 'S&P 500 Prices')
plt.show()

# %%
df_comp.nikkei.plot(figsize=(20,5),title = 'NIKKEI 225 Prices')
plt.show()

# %%
# combining all ->

df_comp.spx.plot(figsize=(30,10),title = 'S&P 500 Prices')
df_comp.nikkei.plot(figsize=(30,10),title = 'NIKKEI 225 Prices')
df_comp.ftse.plot(figsize=(30,10),title = 'FTSE 100 Prices')
df_comp.dax.plot(figsize=(30,10),title = 'DAX 30 Prices')
plt.title("S&P vs NIKKEI vs FTSE vs  DAX")
plt.legend()
plt.show()

# %%
#QQ Plot

import scipy.stats
import pylab

# %%
scipy.stats.probplot(df_comp.spx, plot=pylab)
pylab.show()

# %%
df_comp.date.describe()
# Out:
# count           6269
# unique          6269
# top       07/01/1994
# freq               1
# Name: date, dtype: object

# %%
df_comp.date = pd.to_datetime(df_comp.date,dayfirst=True)

# %%
df_comp.head()
# Out:
#         date     spx      dax     ftse    nikkei
# 0 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1 1994-01-10  475.27  2225.00  3440.58  18443.44
# 2 1994-01-11  474.13  2228.10  3413.77  18485.25
# 3 1994-01-12  474.17  2182.06  3372.02  18793.88
# 4 1994-01-13  472.47  2142.37  3360.01  18577.26

# %%
## to verify date column does not contain text ->

df_comp.date.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   This is separate from the ipykernel package so we can avoid doing imports until
# count                    6269
# unique                   6269
# top       1994-01-07 00:00:00
# freq                        1
# first     1994-01-07 00:00:00
# last      2018-01-29 00:00:00
# Name: date, dtype: object
